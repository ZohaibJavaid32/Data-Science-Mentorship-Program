# %% [markdown]
# <a href="https://colab.research.google.com/github/ZohaibJavaid32/Data-Science-Mentorship-Program/blob/main/Copy_of_session_16_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
empty_series = pd.Series(index = [] , dtype = 'int64')
empty_series
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here

series1 = pd.Series([1,3,5,7,9,11,13,15])
series2 = pd.Series([0,2,4,6,8,10,12,14])

sum = series1 + series2
diff = series1 - series2
div = series1 / series2
multiply = series1 * series2

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
series1 = pd.Series([2, 4, 6, 8, 10])
series2 = pd.Series( [1, 3, 5, 7, 10])

if (series1.values == series2.values).all():
  print("True")
else:
  print("False")


if series1.equals(series2):
  print("True")
else:
  print("False")
# Out:
# False
# False

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here

def datatype_converter(series , datatype):
  if datatype == 'float':
    return pd.to_numeric(series , errors = 'coerce' , downcast = 'float')




series = pd.Series([1,2,'Python', 2.0, True, 100])
datatype_converter(series , 'float')
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float32

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
br = pd.read_csv('/content/batsman_runs_series.csv')
br.head(10)
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25
# 5     A Dananjaya            4
# 6      A Flintoff           62
# 7        A Kumble           35
# 8       A Manohar          108
# 9        A Mishra          362

# %%
# code here
br.sort_values(ascending=False , by='batsman_run').head(10)
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here

br[br['batsman_run'] > 3000]
# Out:
#              batter  batsman_run
# 27   AB de Villiers         5181
# 46        AM Rahane         4074
# 60        AT Rayudu         4190
# 108        CH Gayle         4997
# 130       DA Warner         5883
# 169    F du Plessis         3403
# 174       G Gambhir         4217
# 251      KA Pollard         3437
# 256      KD Karthik         4377
# 263        KL Rahul         3895
# 328       MK Pandey         3657
# 339        MS Dhoni         4978
# 430       RG Sharma         5881
# 452      RV Uthappa         4954
# 462        S Dhawan         6244
# 493        SK Raina         5536
# 511       SR Watson         3880
# 519       SV Samson         3526
# 569         V Kohli         6634
# 597       YK Pathan         3222

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?
#
# *   List item
# *   List item

# %%
# code here
mean_val = br['batsman_run'].mean()
br[br['batsman_run'] > mean_val].shape[0]
# Out:
# 128

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here
items = pd.read_csv('/content/items.csv')
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
items
# Out:
#                                        item_price
# item_name
# Chips and Fresh Tomato Salsa             676.9197
# Izze                                     960.1497
# Nantucket Nectar                         960.1497
# Chips and Tomatillo-Green Chili Salsa    676.9197
# Chicken Bowl                            4809.2454
# ...                                           ...
# Steak Burrito                           3327.9525
# Steak Burrito                           3327.9525
# Chicken Salad Bowl                      3186.3375
# Chicken Salad Bowl                      2478.2625
# Chicken Salad Bowl                      2478.2625
#
# [4622 rows x 1 columns]

# %%
items.set_index('item_name' , inplace=True)

# %%
items
# Out:
#                                        item_price
# item_name
# Chips and Fresh Tomato Salsa             676.9197
# Izze                                     960.1497
# Nantucket Nectar                         960.1497
# Chips and Tomatillo-Green Chili Salsa    676.9197
# Chicken Bowl                            4809.2454
# ...                                           ...
# Steak Burrito                           3327.9525
# Steak Burrito                           3327.9525
# Chicken Salad Bowl                      3186.3375
# Chicken Salad Bowl                      2478.2625
# Chicken Salad Bowl                      2478.2625
#
# [4622 rows x 1 columns]

# %%
items.isnull().sum()
# Out:
# item_price    0
# dtype: int64

# %%
items['item_price'] = items['item_price'].str.replace('$' , '' , regex=False)
items['item_price'] = items['item_price'].astype('float')

# %%
items['item_price'] = items['item_price'] * 283.23

# %%
items
# Out:
#                                        item_price
# item_name
# Chips and Fresh Tomato Salsa             676.9197
# Izze                                     960.1497
# Nantucket Nectar                         960.1497
# Chips and Tomatillo-Green Chili Salsa    676.9197
# Chicken Bowl                            4809.2454
# ...                                           ...
# Steak Burrito                           3327.9525
# Steak Burrito                           3327.9525
# Chicken Salad Bowl                      3186.3375
# Chicken Salad Bowl                      2478.2625
# Chicken Salad Bowl                      2478.2625
#
# [4622 rows x 1 columns]

# %%
items.fillna(items['item_price'].mean() , inplace=True)

# %%
items.isnull().sum()
# Out:
# item_price    0
# dtype: int64

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here

mean = items['item_price'].mean()
mean
# Out:
# np.float64(2113.7544106299215)

# %%
p30 = items['item_price'].quantile(0.30)
p6 = items['item_price'].quantile(0.06)

print(p30)
print(p6)
# Out:
# 1260.3735000000001
# 354.0375

# %%
plt.hist(items['item_price'] ,bins=50 , color ='skyblue' ,edgecolor='black')
plt.title('Histogram of Prices of Items')
plt.xlabel('Prices of Items')
plt.ylabel('Frequency')
plt.show()

# %%
items[(items['item_price'] > 1000) & (items['item_price'] < 2000)]
# Out:
#                      item_price
# item_name
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
# ...                         ...
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
# Chips and Guacamole   1260.3735
#
# [553 rows x 1 columns]
